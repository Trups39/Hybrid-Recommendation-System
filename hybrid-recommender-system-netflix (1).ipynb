# %% [markdown]
# Movie Recommendation System
#
# Collaborative filtering recommendation systems with MovieLens 20m Datasets
# This dataset was constructed to support participants in the Netflix Prize

# %% [markdown]
# Recommandation system passed to users suggestions on what they might like according to their preferences
# is a machine learning application that offers.

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

movie = pd.read_csv('../input/movielense20m/movie.csv')
rating = pd.read_csv('../input/movielense20m/rating.csv')
df = movie.merge(rating, how="left", on="movieId")

# %%
# Data Preparation
# we specify the parantheses so we don't conflict with movies that have years in their titles
df['year_movie'] = df.title.str.extract('(\(\d\d\d\d\))', expand=False)
#Removing the parentheses
df['year_movie'] = df.year_movie.str.extract('(\d\d\d\d)', expand=False)

#Removing the years from the 'title' column
df['title'] = df.title.str.replace('(\(\d\d\d\d\))', '',regex=True)
# To get rid of all the ending white space characters that might have appeared 
df['title'] = df['title'].apply(lambda x: x.strip())

a = pd.DataFrame(df["title"].value_counts())
rare_movies = a[a["title"] <= 1000].index
common_movies = df[~df["title"].isin(rare_movies)]
user_movie_df = common_movies.pivot_table(index=["userId"], columns=["title"], values="rating")

# %%
# genres
# Every genre is separated by a | so we simply have to call the split function on |
df["genre"] = df["genres"].apply(lambda x: x.split("|")[0])
df.drop("genres", inplace=True, axis=1)
df.head()
# Out:
#    movieId      title  userId  rating            timestamp year_movie  \
# 0        1  Toy Story     3.0     4.0  1999-12-11 13:36:47       1995
# 1        1  Toy Story     6.0     5.0  1997-03-13 17:50:52       1995
# 2        1  Toy Story     8.0     4.0  1996-06-05 13:37:51       1995
# 3        1  Toy Story    10.0     4.0  1999-11-25 02:44:47       1995
# 4        1  Toy Story    11.0     4.5  2009-01-02 01:13:41       1995
#
#        genre
# 0  Adventure
# 1  Adventure
# 2  Adventure
# 3  Adventure
# 4  Adventure

# %%
# editting the date format 
df["timestamp"] = pd.to_datetime(df["timestamp"], format='%Y-%m-%d')
df["year"] = df["timestamp"].dt.year
df["month"] = df["timestamp"].dt.month
df["day"] = df["timestamp"].dt.day
df.head()
# Out:
#    movieId      title  userId  rating           timestamp year_movie  \
# 0        1  Toy Story     3.0     4.0 1999-12-11 13:36:47       1995
# 1        1  Toy Story     6.0     5.0 1997-03-13 17:50:52       1995
# 2        1  Toy Story     8.0     4.0 1996-06-05 13:37:51       1995
# 3        1  Toy Story    10.0     4.0 1999-11-25 02:44:47       1995
# 4        1  Toy Story    11.0     4.5 2009-01-02 01:13:41       1995
#
#        genre    year  month   day
# 0  Adventure  1999.0   12.0  11.0
# 1  Adventure  1997.0    3.0  13.0
# 2  Adventure  1996.0    6.0   5.0
# 3  Adventure  1999.0   11.0  25.0
# 4  Adventure  2009.0    1.0   2.0

# %% [markdown]
# Collaborative Filtering
#
# * This filtering method is usually based on collecting and analyzing information on user’s behaviors,
# their activities or preferences and predicting what they will like based on the similarity with other
# users.
#
# User-User Collaborative Filtering: Here, we try to search for lookalike customers and offer products
# based on what his/her lookalike has chosen. This algorithm is very effective but takes
# a lot of time and resources.

# %%
# choosing random a user
user_id = int(pd.Series(user_movie_df.index).sample(1).values)
user_id
# Out:
# 116684

# %%
# Determining the movies watched by the recommended user
user_df = user_movie_df[user_movie_df.index == user_id]

movies_watched = user_df.columns[user_df.notna().any()].tolist()
len(movies_watched)
# the number of movies the user has watched
# Out:
# 128

# %%
# Accessing data and Ids of other users watching the same movies 
movies_watched_df = user_movie_df[movies_watched]
movies_watched_df.head()
movies_watched_df.shape
# There are 138493 users who watched at least one of the movies the user watched.
# Out:
# (138493, 128)

# %%
# each user watched how many of these 455 movies
user_movie_count = movies_watched_df.T.notnull().sum()
user_movie_count.head()
# Out:
# userId
# 1.0    33
# 2.0    12
# 3.0    35
# 4.0     9
# 5.0    18
# dtype: int64

# %%
user_movie_count = user_movie_count.reset_index()
user_movie_count.columns = ["userId", "movie_count"]
m_count = movies_watched_df.shape[1]   # 455

# choosen a ratio of 0.60. User ids who watched at least percent of 60 these movies 
users_same_movies=user_movie_count[user_movie_count["movie_count"]/m_count > 0.6].sort_values("movie_count", ascending=False)
users_same_movies.nunique()
# Out:
# userId         2257
# movie_count      49
# dtype: int64

# %%
users_same_movies.head(10)
# Out:
#           userId  movie_count
# 116683  116684.0          128
# 83089    83090.0          128
# 118204  118205.0          127
# 8404      8405.0          126
# 92010    92011.0          123
# 118753  118754.0          122
# 80885    80886.0          122
# 57734    57735.0          122
# 76629    76630.0          121
# 107325  107326.0          121

# %% [markdown]
# Determining the most similar users to the user to be recommended

# %%
# We bring together users who watch the same movies with the user. (not overlook the above ratio)
final_df = pd.concat([movies_watched_df[movies_watched_df.index.isin(users_same_movies.index)],
                      user_df[movies_watched]])

final_df.head()
# Out:
# title   12 Angry Men  Air Force One  Alien  Aliens  Assassins  \
# userId
# 53.0             5.0            NaN    NaN     NaN        NaN
# 90.0             NaN            NaN    3.5     NaN        NaN
# 115.0            NaN            NaN    NaN     NaN        NaN
# 155.0            NaN            NaN    4.0     4.0        NaN
# 207.0            NaN            2.0    4.0     3.0        NaN
#
# title   Back to the Future  Bambi  Basic Instinct  Ben-Hur  Blade Runner  \
# userId
# 53.0                   NaN    NaN             NaN      2.0           NaN
# 90.0                   NaN    NaN             NaN      NaN           NaN
# 115.0                  3.0    NaN             NaN      NaN           NaN
# 155.0                  4.0    NaN             NaN      NaN           NaN
# 207.0                  NaN    NaN             NaN      NaN           NaN
#
# title   Bloodsport  Blues Brothers, The  Braveheart  Casablanca  Casino  \
# userId
# 53.0           NaN                  NaN         NaN         3.0     NaN
# 90.0           NaN                  NaN         3.0         NaN     NaN
# 115.0          NaN                  NaN         NaN         NaN     NaN
# 155.0          NaN                  NaN         NaN         2.5     NaN
# 207.0          NaN                  4.0         NaN         NaN     NaN
#
# title   Clear and Present Danger  Con Air  Crocodile Dundee  Die Hard  \
# userId
# 53.0                         NaN      NaN               NaN       NaN
# 90.0                         NaN      3.5               NaN       NaN
# 115.0                        NaN      NaN               NaN       NaN
# 155.0                        NaN      NaN               NaN       NaN
# 207.0                        NaN      2.0               NaN       3.0
#
# title   Die Hard 2  Die Hard: With a Vengeance  Dumbo  Dune  \
# userId
# 53.0           NaN                         NaN    NaN   NaN
# 90.0           NaN                         NaN    NaN   NaN
# 115.0          NaN                         2.5    NaN   NaN
# 155.0          NaN                         NaN    NaN   NaN
# 207.0          NaN                         NaN    NaN   NaN
#
# title   E.T. the Extra-Terrestrial  Elizabeth  Enemy of the State  Entrapment  \
# userId
# 53.0                           5.0        NaN                 NaN         NaN
# 90.0                           NaN        NaN                 NaN         NaN
# 115.0                          NaN        NaN                 NaN         NaN
# 155.0                          NaN        NaN                 NaN         NaN
# 207.0                          NaN        NaN                 NaN         NaN
#
# title   Escape to Witch Mountain  Face/Off  Fantasia  \
# userId
# 53.0                         NaN       NaN       NaN
# 90.0                         NaN       NaN       NaN
# 115.0                        NaN       NaN       NaN
# 155.0                        NaN       NaN       NaN
# 207.0                        NaN       2.0       NaN
#
# title   Farewell My Concubine (Ba wang bie ji)  Fargo  \
# userId
# 53.0                                       5.0    5.0
# 90.0                                       NaN    3.5
# 115.0                                      NaN    NaN
# 155.0                                      NaN    NaN
# 207.0                                      NaN    NaN
#
# title   Femme Nikita, La (Nikita)  Ferris Bueller's Day Off  Firm, The  \
# userId
# 53.0                          NaN                       NaN        NaN
# 90.0                          NaN                       3.0        NaN
# 115.0                         NaN                       NaN        NaN
# 155.0                         NaN                       NaN        NaN
# 207.0                         NaN                       NaN        NaN
#
# title   First Blood (Rambo: First Blood)  For Your Eyes Only  Forrest Gump  \
# userId
# 53.0                                 NaN                 NaN           NaN
# 90.0                                 NaN                 NaN           5.0
# 115.0                                NaN                 NaN           NaN
# 155.0                                NaN                 NaN           NaN
# 207.0                                NaN                 NaN           NaN
#
# title   Four Weddings and a Funeral  French Kiss  Fugitive, The  Glory  \
# userId
# 53.0                            NaN          NaN            NaN    NaN
# 90.0                            NaN          NaN            NaN    NaN
# 115.0                           NaN          NaN            NaN    NaN
# 155.0                           NaN          NaN            NaN    NaN
# 207.0                           NaN          NaN            NaN    NaN
#
# title   Godfather, The  Godfather: Part II, The  Godfather: Part III, The  \
# userId
# 53.0               4.0                      4.0                       NaN
# 90.0               NaN                      NaN                       NaN
# 115.0              4.0                      NaN                       NaN
# 155.0              2.0                      NaN                       NaN
# 207.0              5.0                      5.0                       NaN
#
# title   Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il)  \
# userId
# 53.0                                                  NaN
# 90.0                                                  NaN
# 115.0                                                 NaN
# 155.0                                                 NaN
# 207.0                                                 NaN
#
# title   Goodfellas  Grease  Hand That Rocks the Cradle, The  Heartbreak Ridge  \
# userId
# 53.0           NaN     NaN                              NaN               NaN
# 90.0           NaN     NaN                              NaN               NaN
# 115.0          NaN     NaN                              NaN               NaN
# 155.0          NaN     NaN                              NaN               NaN
# 207.0          NaN     NaN                              NaN               NaN
#
# title   High Noon  Highlander  Holiday Inn  Hunt for Red October, The  I.Q.  \
# userId
# 53.0          NaN         NaN          NaN                        NaN   NaN
# 90.0          NaN         NaN          NaN                        NaN   NaN
# 115.0         NaN         NaN          NaN                        NaN   NaN
# 155.0         NaN         NaN          NaN                        NaN   NaN
# 207.0         NaN         NaN          NaN                        3.0   NaN
#
# title   Indiana Jones and the Last Crusade  \
# userId
# 53.0                                   NaN
# 90.0                                   4.0
# 115.0                                  NaN
# 155.0                                  3.5
# 207.0                                  NaN
#
# title   Indiana Jones and the Temple of Doom  It's a Wonderful Life  \
# userId
# 53.0                                     NaN                    NaN
# 90.0                                     NaN                    NaN
# 115.0                                    NaN                    NaN
# 155.0                                    NaN                    NaN
# 207.0                                    NaN                    NaN
#
# title   Joy Luck Club, The  Jumanji  Kazaam  \
# userId
# 53.0                   NaN      NaN     NaN
# 90.0                   NaN      NaN     NaN
# 115.0                  NaN      NaN     NaN
# 155.0                  NaN      NaN     NaN
# 207.0                  NaN      NaN     NaN
#
# title   Killer, The (Die xue shuang xiong)  Killing Fields, The  \
# userId
# 53.0                                   NaN                  5.0
# 90.0                                   NaN                  NaN
# 115.0                                  NaN                  NaN
# 155.0                                  NaN                  NaN
# 207.0                                  NaN                  NaN
#
# title   King and I, The  Legend  Legends of the Fall  Lethal Weapon  \
# userId
# 53.0                NaN     NaN                  NaN            NaN
# 90.0                NaN     NaN                  NaN            NaN
# 115.0               NaN     NaN                  NaN            NaN
# 155.0               NaN     NaN                  NaN            NaN
# 207.0               NaN     NaN                  NaN            3.0
#
# title   Lethal Weapon 2  Little Mermaid, The  \
# userId
# 53.0                NaN                  NaN
# 90.0                NaN                  3.0
# 115.0               NaN                  NaN
# 155.0               NaN                  NaN
# 207.0               NaN                  NaN
#
# title   Léon: The Professional (a.k.a. The Professional) (Léon)  Mask, The  \
# userId
# 53.0                                                  NaN              NaN
# 90.0                                                  NaN              3.5
# 115.0                                                 NaN              NaN
# 155.0                                                 NaN              NaN
# 207.0                                                 NaN              NaN
#
# title   Matrix, The  Meet Me in St. Louis  Moonraker  \
# userId
# 53.0            NaN                   NaN        NaN
# 90.0            2.0                   NaN        NaN
# 115.0           4.0                   NaN        NaN
# 155.0           5.0                   NaN        NaN
# 207.0           NaN                   NaN        NaN
#
# title   My Life as a Dog (Mitt liv som hund)  Negotiator, The  Out of Sight  \
# userId
# 53.0                                     5.0              NaN           NaN
# 90.0                                     NaN              NaN           NaN
# 115.0                                    NaN              NaN           NaN
# 155.0                                    NaN              NaN           NaN
# 207.0                                    NaN              NaN           4.0
#
# title   Patriot Games  Patriot, The  Peacemaker, The  \
# userId
# 53.0              NaN           NaN              NaN
# 90.0              NaN           4.5              NaN
# 115.0             NaN           NaN              NaN
# 155.0             NaN           NaN              NaN
# 207.0             NaN           NaN              NaN
#
# title   Postman, The (Postino, Il)  Predator  Pulp Fiction  \
# userId
# 53.0                           5.0       NaN           3.0
# 90.0                           NaN       NaN           3.5
# 115.0                          NaN       NaN           5.0
# 155.0                          NaN       NaN           5.0
# 207.0                          NaN       NaN           NaN
#
# title   Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark)  \
# userId
# 53.0                                                  3.0
# 90.0                                                  NaN
# 115.0                                                 4.0
# 155.0                                                 3.5
# 207.0                                                 4.0
#
# title   Ransom  Reservoir Dogs  Road Warrior, The (Mad Max 2)  Rob Roy  \
# userId
# 53.0       NaN             NaN                            NaN      NaN
# 90.0       NaN             NaN                            NaN      NaN
# 115.0      NaN             4.5                            NaN      NaN
# 155.0      NaN             NaN                            NaN      NaN
# 207.0      NaN             NaN                            NaN      NaN
#
# title   RoboCop  Rock, The  Roman Holiday  Romeo Must Die  Running Man, The  \
# userId
# 53.0        NaN        NaN            NaN             NaN               NaN
# 90.0        NaN        3.5            NaN             NaN               NaN
# 115.0       NaN        NaN            NaN             NaN               NaN
# 155.0       NaN        NaN            NaN             NaN               NaN
# 207.0       NaN        3.0            NaN             NaN               NaN
#
# title   Rush Hour  Seven (a.k.a. Se7en)  Siege, The  \
# userId
# 53.0          NaN                   NaN         NaN
# 90.0          NaN                   4.5         NaN
# 115.0         NaN                   4.5         NaN
# 155.0         NaN                   NaN         NaN
# 207.0         NaN                   NaN         NaN
#
# title   Silence of the Lambs, The  Singin' in the Rain  Sixth Sense, The  \
# userId
# 53.0                          NaN                  NaN               NaN
# 90.0                          3.5                  NaN               4.0
# 115.0                         NaN                  NaN               3.5
# 155.0                         NaN                  NaN               3.5
# 207.0                         NaN                  NaN               NaN
#
# title   Sleepless in Seattle  Sleepy Hollow  Species  Speed  \
# userId
# 53.0                     NaN            NaN      NaN    NaN
# 90.0                     NaN            NaN      NaN    2.5
# 115.0                    NaN            NaN      NaN    1.5
# 155.0                    NaN            NaN      NaN    NaN
# 207.0                    NaN            NaN      NaN    3.0
#
# title   Star Wars: Episode I - The Phantom Menace  \
# userId
# 53.0                                          NaN
# 90.0                                          3.0
# 115.0                                         NaN
# 155.0                                         NaN
# 207.0                                         NaN
#
# title   Star Wars: Episode IV - A New Hope  \
# userId
# 53.0                                   NaN
# 90.0                                   3.5
# 115.0                                  NaN
# 155.0                                  4.5
# 207.0                                  4.0
#
# title   Star Wars: Episode V - The Empire Strikes Back  \
# userId
# 53.0                                               NaN
# 90.0                                               3.5
# 115.0                                              NaN
# 155.0                                              4.5
# 207.0                                              3.0
#
# title   Star Wars: Episode VI - Return of the Jedi  Strictly Ballroom  \
# userId
# 53.0                                           NaN                NaN
# 90.0                                           4.0                NaN
# 115.0                                          NaN                NaN
# 155.0                                          4.0                NaN
# 207.0                                          3.0                NaN
#
# title   Superman II  Terminator 2: Judgment Day  Terminator, The  \
# userId
# 53.0            NaN                         NaN              NaN
# 90.0            NaN                         3.0              NaN
# 115.0           NaN                         NaN              NaN
# 155.0           NaN                         NaN              NaN
# 207.0           NaN                         3.0              4.0
#
# title   Thomas Crown Affair, The  Three Colors: Blue (Trois couleurs: Bleu)  \
# userId
# 53.0                         NaN                                        NaN
# 90.0                         NaN                                        NaN
# 115.0                        NaN                                        NaN
# 155.0                        NaN                                        NaN
# 207.0                        NaN                                        NaN
#
# title   Three Colors: Red (Trois couleurs: Rouge)  Titanic  \
# userId
# 53.0                                          NaN      2.0
# 90.0                                          NaN      2.5
# 115.0                                         NaN      NaN
# 155.0                                         NaN      NaN
# 207.0                                         NaN      3.0
#
# title   To Kill a Mockingbird  Total Recall  Toy Story  Toys  Tron  True Lies  \
# userId
# 53.0                      5.0           NaN        4.0   NaN   NaN        NaN
# 90.0                      4.0           NaN        3.5   NaN   NaN        4.5
# 115.0                     NaN           NaN        1.5   NaN   NaN        NaN
# 155.0                     NaN           NaN        2.5   NaN   NaN        NaN
# 207.0                     NaN           NaN        NaN   NaN   NaN        1.0
#
# title   Twelve Monkeys (a.k.a. 12 Monkeys)  Usual Suspects, The  \
# userId
# 53.0                                   4.0                  5.0
# 90.0                                   NaN                  NaN
# 115.0                                  NaN                  NaN
# 155.0                                  4.5                  4.0
# 207.0                                  NaN                  NaN
#
# title   When Harry Met Sally...  While You Were Sleeping  White Christmas  \
# userId
# 53.0                        NaN                      NaN              NaN
# 90.0                        NaN                      NaN              NaN
# 115.0                       NaN                      NaN              NaN
# 155.0                       NaN                      NaN              NaN
# 207.0                       NaN                      NaN              NaN
#
# title   Willow  Witness
# userId
# 53.0       NaN      NaN
# 90.0       NaN      NaN
# 115.0      NaN      NaN
# 155.0      NaN      NaN
# 207.0      NaN      NaN

# %%
corr_df = final_df.T.corr().unstack().sort_values().drop_duplicates()
corr_df = pd.DataFrame(corr_df, columns=["corr"])
corr_df.index.names = ['user_id_1', 'user_id_2']
corr_df = corr_df.reset_index()
corr_df.head()
# Out:
#    user_id_1  user_id_2  corr
# 0    50745.0    47985.0  -1.0
# 1    37316.0    13848.0  -1.0
# 2    55236.0     4149.0  -1.0
# 3    66532.0    88819.0  -1.0
# 4    48643.0   125584.0  -1.0

# %% [markdown]
# We are interested in users who have a high correlation with the user_id.
# Could analysis it by entering a value

# %%
top_users = corr_df[(corr_df["user_id_1"] == user_id) & (corr_df["corr"] >= 0.60)][
    ["user_id_2", "corr"]].reset_index(drop=True)

top_users = top_users.sort_values(by='corr', ascending=False)

# Users who have more than 0.60 corr with the user
top_users.rename(columns={"user_id_2": "userId"}, inplace=True) 
top_users.T
# Out:
#                    15             14            13            12  \
# userId  135424.000000  126394.000000  15836.000000  94627.000000
# corr         0.908108       0.783092      0.768854      0.766419
#
#                    11             10             9             8   \
# userId  125895.000000  137163.000000  104062.000000  37293.000000
# corr         0.678287       0.677631       0.676209      0.663947
#
#                    7             6             5           4             3   \
# userId  100253.000000  26066.000000  25959.000000  6920.00000  44295.000000
# corr         0.641026      0.629059      0.608175     0.60746      0.605206
#
#                   2             1              0
# userId  85653.000000  80390.000000  113072.000000
# corr        0.604254      0.603055       0.602512

# %%
# Calculation weighted rating
rating = pd.read_csv('../input/movielense20m/rating.csv')
top_users_ratings = top_users.merge(rating[["userId", "movieId", "rating"]], how='inner')
top_users_ratings['weighted_rating'] = top_users_ratings['corr'] * top_users_ratings['rating']
top_users_ratings.head()
# Out:
#      userId      corr  movieId  rating  weighted_rating
# 0  135424.0  0.908108        1     4.0         3.632433
# 1  135424.0  0.908108        3     3.0         2.724325
# 2  135424.0  0.908108        5     3.0         2.724325
# 3  135424.0  0.908108       14     2.0         1.816217
# 4  135424.0  0.908108       25     2.0         1.816217

# %%
# Calculating the weighted average recommendation score and keeping the top ten films
# Unique rating for movieId 
temp = top_users_ratings.groupby('movieId').sum()[['corr', 'weighted_rating']]
temp.columns = ['sum_corr', 'sum_weighted_rating']
temp.head()
# Out:
#          sum_corr  sum_weighted_rating
# movieId
# 1        2.189450             7.476458
# 2        1.232115             4.325403
# 3        0.908108             2.724325
# 5        1.537168             5.869621
# 10       1.885596             5.656789

# %%
# Calculating weighted average recommendation score and keeping top five films based on scores
recommendation_df = pd.DataFrame()
recommendation_df['weighted_average_recommendation_score'] = temp['sum_weighted_rating'] / temp['sum_corr']
recommendation_df['movieId'] = temp.index
recommendation_df = recommendation_df.sort_values(by='weighted_average_recommendation_score', ascending=False)
recommendation_df.head(7)
# Out:
#          weighted_average_recommendation_score  movieId
# movieId
# 109374                                     5.0   109374
# 2948                                       5.0     2948
# 2692                                       5.0     2692
# 1117                                       5.0     1117
# 425                                        5.0      425
# 1148                                       5.0     1148
# 2745                                       5.0     2745

# %%
# movies that the user may like
movie = pd.read_csv('../input/movielense20m/movie.csv')
movie.loc[movie['movieId'].isin(recommendation_df.head(10)['movieId'])]
# Out:
#        movieId                                           title  \
# 421        425                                 Blue Sky (1994)
# 1094      1117      Eighth Day, The (Huitième jour, Le) (1996)
# 1125      1148     Wallace & Gromit: The Wrong Trousers (1993)
# 1149      1172  Cinema Paradiso (Nuovo cinema Paradiso) (1989)
# 2606      2692                Run Lola Run (Lola rennt) (1998)
# 2659      2745                             Mission, The (1986)
# 2705      2791                                Airplane! (1980)
# 2711      2797                                      Big (1988)
# 2862      2948                    From Russia with Love (1963)
# 22880   109374                Grand Budapest Hotel, The (2014)
#
#                                 genres
# 421                      Drama|Romance
# 1094                             Drama
# 1125   Animation|Children|Comedy|Crime
# 1149                             Drama
# 2606                      Action|Crime
# 2659                             Drama
# 2705                            Comedy
# 2711      Comedy|Drama|Fantasy|Romance
# 2862         Action|Adventure|Thriller
# 22880                     Comedy|Drama

# %%
user_df = df.loc[df["userId"]==user_id]
user_df.head()
# Out:
#         movieId                               title    userId  rating  \
# 41940         1                           Toy Story  116684.0     3.0
# 68447         2                             Jumanji  116684.0     3.0
# 217895       16                              Casino  116684.0     3.0
# 309110       23                           Assassins  116684.0     3.0
# 404010       32  Twelve Monkeys (a.k.a. 12 Monkeys)  116684.0     3.0
#
#                  timestamp year_movie      genre    year  month   day
# 41940  2000-06-20 00:57:44       1995  Adventure  2000.0    6.0  20.0
# 68447  2000-06-21 00:02:30       1995  Adventure  2000.0    6.0  21.0
# 217895 2000-06-21 00:17:31       1995      Crime  2000.0    6.0  21.0
# 309110 2000-06-21 00:19:03       1995     Action  2000.0    6.0  21.0
# 404010 2000-06-20 00:45:26       1995    Mystery  2000.0    6.0  20.0

# %%
user_df.groupby("title").agg({"rating": "max", "timestamp": "max"}).sort_values("timestamp", ascending=False)
# Out:
#                                                     rating           timestamp
# title
# Species                                                3.0 2000-06-21 00:40:02
# Braveheart                                             5.0 2000-06-21 00:38:17
# Blade Runner                                           5.0 2000-06-21 00:38:00
# Superman II                                            4.0 2000-06-21 00:32:25
# First Blood (Rambo: First Blood)                       4.0 2000-06-21 00:32:08
# Running Man, The                                       4.0 2000-06-21 00:32:08
# Heartbreak Ridge                                       3.0 2000-06-21 00:32:08
# Indiana Jones and the Temple of Doom                   4.0 2000-06-21 00:31:36
# Bloodsport                                             4.0 2000-06-21 00:31:36
# For Your Eyes Only                                     4.0 2000-06-21 00:31:13
# Blues Brothers, The                                    4.0 2000-06-21 00:31:13
# Lethal Weapon 2                                        4.0 2000-06-21 00:31:13
# Highlander                                             4.0 2000-06-21 00:30:42
# RoboCop                                                4.0 2000-06-21 00:30:42
# Raiders of the Lost Ark (Indiana Jones and the ...     4.0 2000-06-21 00:30:22
# Star Wars: Episode V - The Empire Strikes Back         3.0 2000-06-21 00:30:22
# Glory                                                  4.0 2000-06-21 00:30:22
# Road Warrior, The (Mad Max 2)                          4.0 2000-06-21 00:30:22
# Entrapment                                             3.0 2000-06-21 00:20:11
# Assassins                                              3.0 2000-06-21 00:19:03
# Peacemaker, The                                        2.0 2000-06-21 00:19:03
